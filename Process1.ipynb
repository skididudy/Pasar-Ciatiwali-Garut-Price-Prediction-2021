# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('komoditas-2020.csv')

# %%
data
# Out:
#          Tanggal  Beras Premium   Beras Medium   Minyak Goreng Curah   \
# 0      2 Januari         12,000         10,500                10,000
# 1      6 Januari         10,500          9,500                 9,500
# 2      9 Januari         11,000         10,000                 9,500
# 3     13 Januari         10,500          9,500                 9,500
# 4     16 Januari         11,500         10,500                10,500
# ..           ...             ...            ...                   ...
# 99   18 Desember         11,500         10,500                14,000
# 100  22 Desember         11,500         10,500                13,500
# 101  24 Desember         11,500         10,500                13,500
# 102  28 Desember         11,500         10,500                13,500
# 103  31 Desember         11,500         10,500                13,500
#
#      Gula Pasir  Terigu Segitiga Biru Bawang Merah Bawang Putih  \
# 0        13,000                8,500       35,000       26,000
# ...

# %%
data.isnull().sum()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=data['Tanggal'], y= data['Terigu Segitiga Biru'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
data.dtypes

# %%
data = pd.DataFrame(data)

# Remove spaces from column names
data = data.rename(columns=lambda x: x.replace(' ', ''))

# Print the modified DataFrame with updated column names
print(data)
# Out:
#          Tanggal BerasPremium BerasMedium MinyakGorengCurah GulaPasir  \
# 0      2 Januari      12,000      10,500            10,000    13,000
# 1      6 Januari      10,500       9,500             9,500    11,500
# 2      9 Januari      11,000      10,000             9,500    12,000
# 3     13 Januari      10,500       9,500             9,500    12,000
# 4     16 Januari      11,500      10,500            10,500    13,000
# ..           ...          ...         ...               ...       ...
# 99   18 Desember      11,500      10,500            14,000    13,500
# 100  22 Desember      11,500      10,500            13,500    13,000
# 101  24 Desember      11,500      10,500            13,500    13,000
# 102  28 Desember      11,500      10,500            13,500    13,000
# 103  31 Desember      11,500      10,500            13,500    13,000
#
#     TeriguSegitigaBiru BawangMerah BawangPutih CabeRawitMerah  \
# 0               8,500      35,000      26,000         40,000
# ...

# %%
df = data

# %%
import pandas as pd

# Define a dictionary to map month names
month_mapping = {
    'januari': 'January',
    'februari': 'February',
    'maret': 'March',
    'april': 'April',
    'mei': 'May',
    'juni': 'June',
    'juli': 'July',
    'agustus': 'August',
    'september': 'September',
    'oktober': 'October',
    'november': 'November',
    'desember': 'December'
}

# Replace month names in a column using a lambda function with regular expressions
df['Tanggal'] = df['Tanggal'].apply(lambda x: ' '.join([month_mapping.get(word.lower(), word) for word in x.split()]))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert 'Tanggal' column to datetime format
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d %B')

# %%
df
# Out:
#        Tanggal BerasPremium BerasMedium MinyakGorengCurah GulaPasir  \
# 0   2020-01-02      12,000      10,500            10,000    13,000
# 1   2020-01-06      10,500       9,500             9,500    11,500
# 2   2020-01-09      11,000      10,000             9,500    12,000
# 3   2020-01-13      10,500       9,500             9,500    12,000
# 4   2020-01-16      11,500      10,500            10,500    13,000
# ..         ...          ...         ...               ...       ...
# 99  2020-12-18      11,500      10,500            14,000    13,500
# 100 2020-12-22      11,500      10,500            13,500    13,000
# 101 2020-12-24      11,500      10,500            13,500    13,000
# 102 2020-12-28      11,500      10,500            13,500    13,000
# 103 2020-12-31      11,500      10,500            13,500    13,000
#
#     TeriguSegitigaBiru BawangMerah BawangPutih CabeRawitMerah  \
# 0               8,500      35,000      26,000         40,000
# ...

# %%
df['Tanggal'] = df['Tanggal'].apply(lambda x: x.replace(year=2020))

# %%
df.to_csv('DataGarut.csv')
